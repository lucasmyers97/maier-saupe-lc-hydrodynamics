# %%
import scipy.io as sio

# %%
filename = "PlusHalfQ.mat"
data = sio.loadmat(filename)
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Mon Aug  9 14:36:24 2021',
#  '__version__': '1.0',
#  '__globals__': [],
#  'Q': array([[[[-0.12616723, -0.12522938, -0.12428049, ...,  0.34931382,
#             0.35026272,  0.35120056],
#           [-0.1271014 , -0.12615683, -0.12520495, ...,  0.35023332,
#             0.35118777,  0.35213473],
#           [-0.12803917, -0.12709185, -0.1261386 , ...,  0.35116158,
#             0.35212009,  0.3530725 ],
#           ...,
#           [-0.12803917, -0.12709188, -0.12613864, ...,  0.35116163,
#             0.35212011,  0.3530725 ],
#           [-0.1271014 , -0.12615684, -0.12520498, ...,  0.35023334,
#             0.35118779,  0.35213473],
#           [-0.12616723, -0.12522938, -0.12428049, ...,  0.34931382,
#             0.35026272,  0.35120056]],
#
#          [[-0.23868389, -0.23961807, -0.24055584, ..., -0.24055584,
#            -0.23961807, -0.23868389],
# ...

# %%
Q = data['Q']
X = data['X']
Y = data['Y']

# %% [markdown]
# ## Try to write it as hdf5 file

# %%
import h5py
import numpy as np

# %%
data = np.linspace(0, 2*np.pi, num=1000)

# %%
with h5py.File("mytestfile.hdf5", "w") as f:
     dset = f.create_dataset("mydataset", data.shape, dtype=np.double, data=data)

# %%
f = h5py.File('mytestfile.hdf5', 'r')

# %%
list(f.keys())
# Out:
# ['mydataset']

# %%
dset = f['mydataset']

# %%
data = np.zeros(dset.shape)

# %%
dset.read_direct(data)
data
# Out:
# array([0.        , 0.00628947, 0.01257895, 0.01886842, 0.0251579 ,
#        0.03144737, 0.03773685, 0.04402632, 0.0503158 , 0.05660527,
#        0.06289475, 0.06918422, 0.0754737 , 0.08176317, 0.08805265,
#        0.09434212, 0.1006316 , 0.10692107, 0.11321055, 0.11950002,
#        0.1257895 , 0.13207897, 0.13836845, 0.14465792, 0.15094739,
#        0.15723687, 0.16352634, 0.16981582, 0.17610529, 0.18239477,
#        0.18868424, 0.19497372, 0.20126319, 0.20755267, 0.21384214,
#        0.22013162, 0.22642109, 0.23271057, 0.23900004, 0.24528952,
#        0.25157899, 0.25786847, 0.26415794, 0.27044742, 0.27673689,
#        0.28302637, 0.28931584, 0.29560531, 0.30189479, 0.30818426,
#        0.31447374, 0.32076321, 0.32705269, 0.33334216, 0.33963164,
#        0.34592111, 0.35221059, 0.35850006, 0.36478954, 0.37107901,
#        0.37736849, 0.38365796, 0.38994744, 0.39623691, 0.40252639,
#        0.40881586, 0.41510534, 0.42139481, 0.42768429, 0.43397376,
# ...

# %%
f.close()

# %% [markdown]
# ## Write Cody's data to hdf5

# %%
with h5py.File("plus-half-defect-cody.hdf5", "w") as f:
    dset = f.create_dataset("Q1", Q[0, 0].shape, dtype=np.double, data=Q[0, 0])
    dset = f.create_dataset("Q2", Q[0, 1].shape, dtype=np.double, data=Q[0, 1])
    dset = f.create_dataset("Q3", Q[0, 2].shape, dtype=np.double, data=Q[0, 2])
    dset = f.create_dataset("Q4", Q[1, 1].shape, dtype=np.double, data=Q[1, 1])
    dset = f.create_dataset("Q5", Q[1, 2].shape, dtype=np.double, data=Q[1, 2])
    
    dset = f.create_dataset("X", X.shape, dtype=np.double, data=X)
    dset = f.create_dataset("Y", Y.shape, dtype=np.double, data=Y)

# %%
with h5py.File("plus-half-defect-cody.hdf5", "r") as f:
    Q1_dset = f['Q1']
    Q1_data = np.zeros(Q1_dset.shape)
    Q1_dset.read_direct(Q1_data)
